# %%
import PyPDF2

# %%
with open('Adeyemi_palmpay.pdf', 'rb') as file:
    reader = PyPDF2.PdfReader(file)
    text = ''
    # 모든 페이지의 텍스트 추출
    for page_num in range(len(reader.pages)):
        page = reader.pages[page_num]
        text += page.extract_text()
print(text)
# Out:
# Account StatementName
# Phone Number
# Account Number
# Total Money In ₦923,583.30 Statement Period 07/30/2024 - 10/30/2024
# Total Money Out ₦1,801,102.25 Print Time 10/30/2024 11:07:01 AM
# Transaction Date Transaction Detail Money In (NGN) Money Out (NGN) Transaction ID
# 10/30/2024 09:18:19 AM -2150.00 032bkv5599501
# 10/30/2024 06:26:42 AM CashBox Auto Save -10.00 at_2bkn7460100
# 10/30/2024 06:26:32 AM Received from TrustyTrusty +10.00 602bkn6u9da00
# 10/30/2024 06:10:50 AM CashBox Interest +16.49 u82bkmgo5216e
# 10/29/2024 06:49:43 PM CashBox Auto Save -41500.00 at_2bjqxh43404
# 10/29/2024 06:49:36 PMReceived from ADEYEMI
# KAYODE DAVID+41500.00 602bjqxa9d001
# 10/29/2024 04:58:13 PM Daily Flash Sales -930.00 132bjlrnaf101
# 10/29/2024 02:43:34 PMSend to OLASUNKANMI
# OPEYEMI BAMIDELE-11000.00 032bjfj89c802
# 10/29/2024 02:39:57 PM CashBox Auto Save -13000.00 at_2bjfd763001
# 10/29/2024 02:39:45 PM +13000.00 602bjfcv9c904
# 10/29/2024 01:41:05 PMSend to GROCERY BAZAAR
# ...

# %%
text
