# %%
import requests
import pandas as pd
import json

# API 설정
url = "https://api.dojah.io/api/v1/kyc/bvn/advance"
bvn = "22294573057"  # BVN 번호

# API 헤더 설정 (실제 키로 교체 필요)
headers = {
    "Authorization": "prod_sk_eu9FGSGIMswm1ANa9NsPBNUhH",
    "AppId": "66b48190645a7b004028347b",
    "Content-Type": "application/json"
}

# 결과를 저장할 빈 DataFrame 생성
all_results = pd.DataFrame()

for bvn in bvn_list:
    try:
        # API 요청 보내기
        response = requests.get(f"{url}?bvn={bvn}", headers=headers)
        
        # 응답 확인
        if response.status_code == 200:
            # JSON 응답을 딕셔너리로 변환
            data = response.json()
            
            # DataFrame 생성
            if 'entity' in data:
                df = pd.DataFrame([data['entity']])
            else:
                df = pd.DataFrame([data])
            
            # image 컬럼만 제외
            if 'image' in df.columns:
                df = df.drop('image', axis=1)
            
            # 결과를 전체 DataFrame에 추가
            all_results = pd.concat([all_results, df], ignore_index=True)
            
            print(f"BVN {bvn} 처리 완료")
        else:
            print(f"BVN {bvn} 처리 실패: {response.status_code}")
            print(response.text)
        
    except Exception as e:
        print(f"BVN {bvn} 처리 중 오류 발생: {str(e)}")
        continue
    

# 모든 결과를 CSV 파일로 저장
if not all_results.empty:
    all_results.to_csv('bvn_results.csv', index=False, encoding='utf-8')
    print("모든 데이터가 성공적으로 CSV 파일로 저장되었습니다.")
else:
    print("저장할 데이터가 없습니다.")
# Out:
# BVN 22196985084 처리 완료
# BVN 22294573057 처리 완료
# BVN 22362302659 처리 완료
# BVN 22637742151 처리 완료
# BVN 22606758066 처리 완료
# BVN 22372904698 처리 완료
# BVN 22365301091 처리 완료
# BVN 22195563113 처리 완료
# BVN 22173694390 처리 완료
# BVN 22668597377 처리 완료
# BVN 22550270838 처리 완료
# BVN 22362027895 처리 완료
# BVN 22555802302 처리 완료
# BVN 22537675829 처리 완료
# BVN 22182526150 처리 완료
# BVN 22230652796 처리 완료
# BVN 22402486954 처리 완료
# BVN 22142783843 처리 완료
# BVN 22156628442 처리 완료
# BVN 22211872584 처리 완료
# BVN 22264840439 처리 완료
# BVN 22146446575 처리 완료
# BVN 22237067058 처리 완료
# BVN 22316652748 처리 완료
# BVN 22291134932 처리 완료
# BVN 22383326038 처리 완료
# BVN 22218430547 처리 완료
# BVN 22286942847 처리 완료
# BVN 22382106024 처리 완료
# BVN 22441156175 처리 완료
# BVN 22685839016 처리 완료
# BVN 22648555979 처리 완료
# BVN 22435518682 처리 완료
# BVN 22182092233 처리 완료
# BVN 22428635598 처리 완료
# BVN 22472069815 처리 완료
# BVN 22287884502 처리 완료
# BVN 22192231574 처리 완료
# BVN 22235102225 처리 완료
# BVN 22324835070 처리 완료
# BVN 22163237239 처리 완료
# ...
